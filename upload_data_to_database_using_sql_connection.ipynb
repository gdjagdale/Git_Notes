# %% [markdown]
# ## Load Necessary Libraries

# %%
import psycopg2
import sqlalchemy
import pandas as pd
import os

# %% [markdown]
# ## Upload Accounts table using psycopg2

# %% [markdown]
# ### Read Dataframe

# %%
accounts=pd.read_excel('C:/Users/Admin/Desktop/Tables/accounts.xlsx')
accounts.head()
# Out:
#      id                name                    website        lat       long  \
# 0  1001             Walmart            www.walmart.com  40.238496 -75.103297
# 1  1011         Exxon Mobil         www.exxonmobil.com  41.169156 -73.849374
# 2  1021               Apple              www.apple.com  42.290495 -76.084009
# 3  1031  Berkshire Hathaway  www.berkshirehathaway.com  40.949021 -75.763898
# 4  1041            McKesson           www.mckesson.com  42.217093 -75.284998
#
#       primary_poc  sales_rep_id
# 0     Tamara Tuma      321500.0
# 1    Sung Shields      321510.0
# 2      Jodee Lupo      321520.0
# 3  Serafina Banda      321530.0
# 4  Angeles Crusoe      321540.0

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### 1. Check Data Types of Dataframe

# %%
accounts.dtypes
# Out:
# id                int64
# name             object
# website          object
# lat             float64
# long            float64
# primary_poc      object
# sales_rep_id    float64
# dtype: object

# %% [markdown]
# #### 2. Convert data types as required in SQL

# %%
replacement={
    'int64':'int',
    'object':'varchar(255)',
    'float64':'numeric'
}

# %%
for i in accounts.columns:
    col=accounts.dtypes.replace(replacement)
print(col)
# Out:
# id                       int
# name            varchar(255)
# website         varchar(255)
# lat                  numeric
# long                 numeric
# primary_poc     varchar(255)
# sales_rep_id         numeric
# dtype: object

# %% [markdown]
# #### 3. Save file in csv format

# %%
os.chdir('C:/Users/Admin/Desktop/Tables/New Folder')
accounts.to_csv('accounts.csv',index=False)

# %% [markdown]
# ### Push Accounts data to Database

# %%
# create connection
connection=psycopg2.connect(user='postgres',
                           password='password',
                           host='localhost',
                           port=5432,
                           database='table_joins')
cursor=connection.cursor()
print("Connection Established Successfully")
# Out:
# Connection Established Successfully

# %%
# create table in database

cursor.execute('''drop table if exists accounts''')
connection.commit()

cursor.execute('''create table accounts 
               (id                       int,
                name            varchar(255),
                website         varchar(255),
                lat                  numeric,
                long                 numeric,
                primary_poc     varchar(255),
                sales_rep_id         numeric)
                ''')
connection.commit()

# %%
# Open accounts.csv file
my_file=open('accounts.csv')

# %%
# copy file content to accounts table in database
statement='''copy accounts from stdin with header csv delimiter as ','
'''
cursor.copy_expert(sql=statement,file=my_file)
connection.commit()

# %% [markdown]
# ### Read file from database

# %%
cursor.execute('''select * from accounts''')
connection.commit()

data=cursor.fetchall()

db_accounts=pd.DataFrame(data,columns=[accounts.columns])
db_accounts
# Out:
#        id                name                    website          lat  \
# 0    1001             Walmart            www.walmart.com  40.23849561
# 1    1011         Exxon Mobil         www.exxonmobil.com   41.1691563
# 2    1021               Apple              www.apple.com  42.29049481
# 3    1031  Berkshire Hathaway  www.berkshirehathaway.com  40.94902131
# 4    1041            McKesson           www.mckesson.com  42.21709326
# ..    ...                 ...                        ...          ...
# 346  4461                 KKR                www.kkr.com  45.54535285
# 347  4471               Oneok              www.oneok.com  45.51351286
# 348  4481      Newmont Mining            www.newmont.com  45.49411669
# 349  4491                 PPL             www.pplweb.com  45.49172048
# 350  4501         SpartanNash        www.spartannash.com         None
#
#               long       primary_poc sales_rep_id
# 0     -75.10329704       Tamara Tuma     321500.0
# 1     -73.84937379      Sung Shields     321510.0
# 2     -76.08400942        Jodee Lupo     321520.0
# 3     -75.76389759    Serafina Banda     321530.0
# 4     -75.28499823    Angeles Crusoe     321540.0
# ..             ...               ...          ...
# 346  -122.65524711       Buffy Azure     321970.0
# 347  -122.68150011   Esta Engelhardt     321960.0
# 348  -122.66946042  Khadijah Riemann     321970.0
# 349  -122.67187978   Deanne Hertlein     321960.0
# 350           None              None         None
#
# [351 rows x 7 columns]

# %% [markdown]
# ## Upload Orders file to Database using sqlalchemy

# %% [markdown]
# ### Read Dataframe

# %%
orders=pd.read_excel("C:/Users/Admin/Desktop/Tables/orders.xlsx")
orders.head()
# Out:
#    id  Account_id               Occurred at  Standard qty  poster_qty  \
# 0   1        1001  2015-10-06T17:31:14.000Z           123          22
# 1   2        1001  2015-11-05T03:34:33.000Z           190          41
# 2   3        1001  2015-12-04T04:21:55.000Z            85          47
# 3   4        1001  2016-01-02T01:18:24.000Z           144          32
# 4   5        1001  2016-02-01T19:27:27.000Z           108          29
#
#    gloss_qty  t$tal  standard/amt_usd  gloss_amt_usd  poster_amt_usd  \
# 0         24    169            613.77         164.78          194.88
# 1         57    288            948.10         307.09          462.84
# 2          0    132            424.15         352.03            0.00
# 3          0    176            718.56         239.68            0.00
# 4         28    165            538.92         217.21          227.36
#
#    total_amt_usd
# 0         973.43
# 1        1718.03
# 2         776.18
# 3         958.24
# 4         983.49

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### 1. Check column names and correct if required

# %%
orders.columns
# Out:
# Index(['id', 'Account_id', 'Occurred at', 'Standard qty', 'poster_qty',
#        'gloss_qty', 't$tal', 'standard/amt_usd', 'gloss_amt_usd',
#        'poster_amt_usd', 'total_amt_usd'],
#       dtype='object')

# %%
replacement={'$':'o',
             '/':'_',
             ' ':'_'
            }

orders.columns=[i.lower().replace("$","o").replace(' ','_').replace('/','_') for i in orders.columns]
orders.columns
# Out:
# Index(['id', 'account_id', 'occurred_at', 'standard_qty', 'poster_qty',
#        'gloss_qty', 'total', 'standard_amt_usd', 'gloss_amt_usd',
#        'poster_amt_usd', 'total_amt_usd'],
#       dtype='object')

# %%
orders.columns
# Out:
# Index(['id', 'account_id', 'occurred_at', 'standard_qty', 'poster_qty',
#        'gloss_qty', 'total', 'standard_amt_usd', 'gloss_amt_usd',
#        'poster_amt_usd', 'total_amt_usd'],
#       dtype='object')

# %% [markdown]
# #### 2.check data types of each column

# %%
orders.dtypes
# Out:
# id                    int64
# account_id            int64
# occurred_at          object
# standard_qty          int64
# poster_qty            int64
# gloss_qty             int64
# total                 int64
# standard_amt_usd    float64
# gloss_amt_usd       float64
# poster_amt_usd      float64
# total_amt_usd       float64
# dtype: object

# %% [markdown]
# #### 3. Change to required SQL Data Types

# %%
replacement={
    'int64':'int',
    'float64':'numeric',
    'object':'varchar(255)'
}

# %%
for i in orders.columns:
    col=orders.dtypes.replace(replacement)
col
# Out:
# id                           int
# account_id                   int
# occurred_at         varchar(255)
# standard_qty                 int
# poster_qty                   int
# gloss_qty                    int
# total                        int
# standard_amt_usd         numeric
# gloss_amt_usd            numeric
# poster_amt_usd           numeric
# total_amt_usd            numeric
# dtype: object

# %% [markdown]
# ###  Split Dataset into 2 groups

# %%
orders1=orders.loc[0:3000]
orders1
# Out:
#         id  account_id               occurred_at  standard_qty  poster_qty  \
# 0        1        1001  2015-10-06T17:31:14.000Z           123          22
# 1        2        1001  2015-11-05T03:34:33.000Z           190          41
# 2        3        1001  2015-12-04T04:21:55.000Z            85          47
# 3        4        1001  2016-01-02T01:18:24.000Z           144          32
# 4        5        1001  2016-02-01T19:27:27.000Z           108          29
# ...    ...         ...                       ...           ...         ...
# 2996  2997        3291  2016-11-09T18:09:43.000Z            69          29
# 2997  2998        3291  2016-12-09T20:43:20.000Z            95          12
# 2998  2999        3301  2016-02-09T07:32:47.000Z           112          22
# 2999  3000        3301  2016-03-09T14:38:49.000Z           118          43
# 3000  3001        3311  2015-09-02T03:06:00.000Z           524          35
#
#       gloss_qty  total  standard_amt_usd  gloss_amt_usd  poster_amt_usd  \
# 0            24    169            613.77         164.78          194.88
# 1            57    288            948.10         307.09          462.84
# 2             0    132            424.15         352.03            0.00
# 3             0    176            718.56         239.68            0.00
# 4            28    165            538.92         217.21          227.36
# ...         ...    ...               ...            ...             ...
# 2996          0     98            344.31         217.21            0.00
# 2997         38    145            474.05          89.88          308.56
# 2998          0    134            558.88         164.78            0.00
# 2999         31    192            588.82         322.07          251.72
# 3000          0    559           2614.76         262.15            0.00
#
#       total_amt_usd
# 0            973.43
# 1           1718.03
# 2            776.18
# 3            958.24
# 4            983.49
# ...             ...
# 2996         561.52
# 2997         872.49
# 2998         723.66
# 2999        1162.61
# 3000        2876.91
#
# [3001 rows x 11 columns]

# %%
orders2=orders.loc[3001:]
orders2
# Out:
#         id  account_id               occurred_at  standard_qty  poster_qty  \
# 3001  3002        3311  2015-10-01T20:15:25.000Z           503          43
# 3002  3003        3311  2015-10-30T09:55:17.000Z           495          13
# 3003  3004        3311  2015-11-28T14:28:03.000Z           496           0
# 3004  3005        3311  2015-12-28T09:44:55.000Z           504          23
# 3005  3006        3311  2016-01-27T20:09:08.000Z           515          21
# ...    ...         ...                       ...           ...         ...
# 6907  6908        4501  2016-06-29T04:03:39.000Z            11         199
# 6908  6909        4501  2016-07-29T19:58:32.000Z             5          91
# 6909  6910        4501  2016-08-27T00:58:11.000Z            16          94
# 6910  6911        4501  2016-11-22T06:52:22.000Z            63          67
# 6911  6912        4501  2016-12-21T13:30:42.000Z            61         150
#
#       gloss_qty  total  standard_amt_usd  gloss_amt_usd  poster_amt_usd  \
# 3001          0    546           2509.97         322.07            0.00
# 3002          0    508           2470.05          97.37            0.00
# 3003         21    517           2475.04           0.00          170.52
# 3004         92    619           2514.96         172.27          747.04
# 3005          5    541           2569.85         157.29           40.60
# ...         ...    ...               ...            ...             ...
# 6907         59    269             54.89        1490.51          479.08
# 6908         96    192             24.95         681.59          779.52
# 6909         82    192             79.84         704.06          665.84
# 6910         81    211            314.37         501.83          657.72
# 6911         52    263            304.39        1123.50          422.24
#
#       total_amt_usd
# 3001        2832.04
# 3002        2567.42
# 3003        2645.56
# 3004        3434.27
# 3005        2767.74
# ...             ...
# 6907        2024.48
# 6908        1486.06
# 6909        1449.74
# 6910        1473.92
# 6911        1850.13
#
# [3911 rows x 11 columns]

# %% [markdown]
# ### Push Data to Database

# %% [markdown]
# #### 1. Create SQL connection

# %%
connection=psycopg2.connect(user='postgres',
                           password='password',
                           host='localhost',
                           port=5432,
                           database='table_joins')
cursor=connection.cursor()
print("Connection Established Successfully")
# Out:
# Connection Established Successfully

# %% [markdown]
# #### 2. Create table in SQL Database

# %%
cursor.execute('''drop table if exists orders''')
connection.commit()

cursor.execute('''create table orders
                (id                           int,
                 account_id                   int,
                 occurred_at          timestamptz,
                 standard_qty                 int,
                 poster_qty                   int,
                 gloss_qty                    int,
                 total                        int,
                 standard_amt_usd         numeric,
                 gloss_amt_usd            numeric,
                 poster_amt_usd           numeric,
                 total_amt_usd            numeric)''')
connection.commit()

# %% [markdown]
# #### 3. Upload orders1 dataframe to orders table in sql

# %%
# create engine
from sqlalchemy import create_engine
engine=create_engine('postgresql://postgres:password@localhost:5432/table_joins')

# %%
orders1.to_sql('orders',con=engine,if_exists='append',index=False)
# Out:
# 1

# %% [markdown]
# #### 4. Upload orders2 dataframe to database table

# %%
# create engine
from sqlalchemy import create_engine
engine=create_engine('postgresql://postgres:password@localhost:5432/table_joins')

# %%
orders2.to_sql('orders',con=engine,if_exists='append',index=False)
# Out:
# 911

# %% [markdown]
# ### Read Data from database

# %%
orders_db=pd.read_sql('select * from orders',engine)
orders_db
# Out:
#         id  account_id               occurred_at  standard_qty  poster_qty  \
# 0        1        1001 2015-10-06 17:31:14+00:00           123          22
# 1        2        1001 2015-11-05 03:34:33+00:00           190          41
# 2        3        1001 2015-12-04 04:21:55+00:00            85          47
# 3        4        1001 2016-01-02 01:18:24+00:00           144          32
# 4        5        1001 2016-02-01 19:27:27+00:00           108          29
# ...    ...         ...                       ...           ...         ...
# 6907  6908        4501 2016-06-29 04:03:39+00:00            11         199
# 6908  6909        4501 2016-07-29 19:58:32+00:00             5          91
# 6909  6910        4501 2016-08-27 00:58:11+00:00            16          94
# 6910  6911        4501 2016-11-22 06:52:22+00:00            63          67
# 6911  6912        4501 2016-12-21 13:30:42+00:00            61         150
#
#       gloss_qty  total  standard_amt_usd  gloss_amt_usd  poster_amt_usd  \
# 0            24    169            613.77         164.78          194.88
# 1            57    288            948.10         307.09          462.84
# 2             0    132            424.15         352.03            0.00
# 3             0    176            718.56         239.68            0.00
# 4            28    165            538.92         217.21          227.36
# ...         ...    ...               ...            ...             ...
# 6907         59    269             54.89        1490.51          479.08
# 6908         96    192             24.95         681.59          779.52
# 6909         82    192             79.84         704.06          665.84
# 6910         81    211            314.37         501.83          657.72
# 6911         52    263            304.39        1123.50          422.24
#
#       total_amt_usd
# 0            973.43
# 1           1718.03
# 2            776.18
# 3            958.24
# 4            983.49
# ...             ...
# 6907        2024.48
# 6908        1486.06
# 6909        1449.74
# 6910        1473.92
# 6911        1850.13
#
# [6912 rows x 11 columns]

# %%
orders_db=pd.read_sql('select total,standard_qty,(total-standard_qty) as remaining from orders',engine)
orders_db
# Out:
#       total  standard_qty  remaining
# 0       169           123         46
# 1       288           190         98
# 2       132            85         47
# 3       176           144         32
# 4       165           108         57
# ...     ...           ...        ...
# 6907    269            11        258
# 6908    192             5        187
# 6909    192            16        176
# 6910    211            63        148
# 6911    263            61        202
#
# [6912 rows x 3 columns]
